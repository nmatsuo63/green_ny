# %%
import pandas as pd
from datetime import datetime

# %%
# 学習用データと評価用データを読み込む
train_org = pd.read_csv('../data/smfg_train.csv', index_col=0)
test_org = pd.read_csv('../data/smfg_test.csv', index_col=0)

# %%
# train由来は0、test由来は1とする列を追加
train_org['is_test'] = 0
test_org['is_test'] = 1

# ユニオン前にカラムを揃える
# testには目的変数（health）が含まれていないので、ダミー変数を追加
test_org['health'] = -1  # 仮の値を割り当て

# trainとtestをユニオン（結合）
dataset = pd.concat([train_org, test_org], ignore_index=True)
dataset[['created_at', 'health', 'tree_dbh', 'steward', 'spc_common', 'nta_name', 'is_test']].head()
# Out:
#    created_at  health  tree_dbh steward          spc_common  \
# 0  2015-06-29       1        14     NaN         English oak
# 1  2016-09-21       1         5    3or4  crimson king maple
# 2  2015-09-13       2        26     NaN         English oak
# 3  2016-05-09       0        15     NaN         honeylocust
# 4  2016-06-24       1        23     NaN    London planetree
#
#                                      nta_name  is_test
# 0        Douglas Manor-Douglaston-Little Neck        0
# 1                  Bedford Park-Fordham North        0
# 2  Annadale-Huguenot-Prince's Bay-Eltingville        0
# 3      Charleston-Richmond Valley-Tottenville        0
# 4           Central Harlem North-Polo Grounds        0

# %% [markdown]
# ### ここから

# %%
df = dataset.copy()
df.head()
# Out:
#    created_at  tree_dbh curb_loc  health steward   guards  sidewalk  \
# 0  2015-06-29        14   OnCurb       1     NaN      NaN    Damage
# 1  2016-09-21         5   OnCurb       1    3or4  Helpful  NoDamage
# 2  2015-09-13        26   OnCurb       2     NaN      NaN  NoDamage
# 3  2016-05-09        15   OnCurb       0     NaN      NaN    Damage
# 4  2016-06-24        23   OnCurb       1     NaN      NaN  NoDamage
#
#          user_type            problems          spc_common  \
# 0        Volunteer                 NaN         English oak
# 1        Volunteer                 NaN  crimson king maple
# 2        Volunteer  StonesBranchLights         English oak
# 3  NYC Parks Staff                 NaN         honeylocust
# 4        Volunteer              Stones    London planetree
#
#                             spc_latin   nta  \
# 0                       Quercus robur  QN45
# 1     Acer platanoides 'Crimson King'  BX05
# 2                       Quercus robur  SI01
# 3  Gleditsia triacanthos var. inermis  SI11
# 4               Platanus x acerifolia  MN03
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist  \
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9
#
#    is_test
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df['health'].value_counts()
# Out:
# health
# -1    19702
#  1    15751
#  0     3535
#  2      698
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# created_at        0
# tree_dbh          0
# curb_loc          0
# health            0
# steward       29409
# guards        29510
# sidewalk          0
# user_type         0
# problems      24288
# spc_common        0
# spc_latin         0
# nta               0
# nta_name          0
# borocode          0
# boro_ct           0
# boroname          0
# zip_city          0
# cb_num            0
# st_senate         0
# st_assem          0
# cncldist          0
# is_test           0
# dtype: int64

# %%
df.fillna('None', inplace=True)

# %%
df.isnull().sum()
# Out:
# created_at    0
# tree_dbh      0
# curb_loc      0
# health        0
# steward       0
# guards        0
# sidewalk      0
# user_type     0
# problems      0
# spc_common    0
# spc_latin     0
# nta           0
# nta_name      0
# borocode      0
# boro_ct       0
# boroname      0
# zip_city      0
# cb_num        0
# st_senate     0
# st_assem      0
# cncldist      0
# is_test       0
# dtype: int64

# %%
df['problems'].value_counts()
# Out:
# problems
# None                                    24288
# Stones                                   4455
# BranchLights                             2045
# StonesBranchLights                       1529
# BranchOther                               793
#                                         ...
# StonesTrunkLightsBranchLights              15
# StonesRootOtherTrunkOtherBranchOther       15
# RootOtherWiresRopeTrunkLights              12
# TrunkLightsBranchLightsBranchOther         12
# WiresRopeTrunkLightsBranchLights            9
# Name: count, Length: 74, dtype: int64

# %%
df['spc_common'].value_counts()
# Out:
# spc_common
# London planetree       4339
# pin oak                4254
# cherry                 3345
# Japanese zelkova       3016
# littleleaf linden      2598
#                        ...
# European beech            6
# Kentucky yellowwood       5
# pond cypress              3
# Chinese chestnut          3
# Himalayan cedar           1
# Name: count, Length: 120, dtype: int64

# %%
df = pd.get_dummies(df, columns=['spc_common'], prefix='name', drop_first = True)
df.head()
# Out:
#    created_at  tree_dbh curb_loc  health steward   guards  sidewalk  \
# 0  2015-06-29        14   OnCurb       1    None     None    Damage
# 1  2016-09-21         5   OnCurb       1    3or4  Helpful  NoDamage
# 2  2015-09-13        26   OnCurb       2    None     None  NoDamage
# 3  2016-05-09        15   OnCurb       0    None     None    Damage
# 4  2016-06-24        23   OnCurb       1    None     None  NoDamage
#
#          user_type            problems                           spc_latin  \
# 0        Volunteer                None                       Quercus robur
# 1        Volunteer                None     Acer platanoides 'Crimson King'
# 2        Volunteer  StonesBranchLights                       Quercus robur
# 3  NYC Parks Staff                None  Gleditsia triacanthos var. inermis
# 4        Volunteer              Stones               Platanus x acerifolia
#
#     nta                                    nta_name  borocode  boro_ct  \
# 0  QN45        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1  BX05                  Bedford Park-Fordham North         2  2039901
# 2  SI01  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3  SI11      Charleston-Richmond Valley-Tottenville         5  5024401
# 4  MN03           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist  \
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9
#
#    is_test  name_American beech  name_American elm  name_American hophornbeam  \
# 0        0                False              False                      False
# 1        0                False              False                      False
# 2        0                False              False                      False
# 3        0                False              False                      False
# 4        0                False              False                      False
#
#    name_American hornbeam  name_American linden  name_Amur cork tree  \
# 0                   False                 False                False
# 1                   False                 False                False
# 2                   False                 False                False
# 3                   False                 False                False
# 4                   False                 False                False
#
#    name_Amur maackia  name_Amur maple  name_Atlantic white cedar  \
# 0              False            False                      False
# 1              False            False                      False
# 2              False            False                      False
# 3              False            False                      False
# 4              False            False                      False
#
#    name_Atlas cedar  name_Callery pear  name_Chinese chestnut  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3             False              False                  False
# 4             False              False                  False
#
#    name_Chinese elm  name_Chinese fringetree  name_Chinese tree lilac  \
# 0             False                    False                    False
# 1             False                    False                    False
# 2             False                    False                    False
# 3             False                    False                    False
# 4             False                    False                    False
#
#    name_Cornelian cherry  name_English oak  name_European beech  \
# 0                  False              True                False
# 1                  False             False                False
# 2                  False              True                False
# 3                  False             False                False
# 4                  False             False                False
#
#    name_European hornbeam  name_Himalayan cedar  name_Japanese hornbeam  \
# 0                   False                 False                   False
# 1                   False                 False                   False
# 2                   False                 False                   False
# 3                   False                 False                   False
# 4                   False                 False                   False
#
#    name_Japanese maple  name_Japanese snowbell  name_Japanese tree lilac  \
# 0                False                   False                     False
# 1                False                   False                     False
# 2                False                   False                     False
# 3                False                   False                     False
# 4                False                   False                     False
#
#    name_Japanese zelkova  name_Kentucky coffeetree  name_Kentucky yellowwood  \
# 0                  False                     False                     False
# 1                  False                     False                     False
# 2                  False                     False                     False
# 3                  False                     False                     False
# 4                  False                     False                     False
#
#    name_London planetree  name_Norway maple  name_Norway spruce  \
# 0                  False              False               False
# 1                  False              False               False
# 2                  False              False               False
# 3                  False              False               False
# 4                   True              False               False
#
#    name_Ohio buckeye  name_Oklahoma redbud  name_Persian ironwood  \
# 0              False                 False                  False
# 1              False                 False                  False
# 2              False                 False                  False
# 3              False                 False                  False
# 4              False                 False                  False
#
#    name_Schumard's oak  name_Shantung maple  name_Siberian elm  name_Sophora  \
# 0                False                False              False         False
# 1                False                False              False         False
# 2                False                False              False         False
# 3                False                False              False         False
# 4                False                False              False         False
#
#    name_Turkish hazelnut  name_arborvitae  name_ash  name_bald cypress  \
# 0                  False            False     False              False
# 1                  False            False     False              False
# 2                  False            False     False              False
# 3                  False            False     False              False
# 4                  False            False     False              False
#
#    name_bigtooth aspen  name_black cherry  name_black locust  name_black oak  \
# 0                False              False              False           False
# 1                False              False              False           False
# 2                False              False              False           False
# 3                False              False              False           False
# 4                False              False              False           False
#
#    name_black walnut  name_blackgum  name_blue spruce  name_bur oak  \
# 0              False          False             False         False
# 1              False          False             False         False
# 2              False          False             False         False
# 3              False          False             False         False
# 4              False          False             False         False
#
#    name_catalpa  name_cherry  name_cockspur hawthorn  name_common hackberry  \
# 0         False        False                   False                  False
# 1         False        False                   False                  False
# 2         False        False                   False                  False
# 3         False        False                   False                  False
# 4         False        False                   False                  False
#
#    name_crab apple  name_crepe myrtle  name_crimson king maple  \
# 0            False              False                    False
# 1            False              False                     True
# 2            False              False                    False
# 3            False              False                    False
# 4            False              False                    False
#
#    name_cucumber magnolia  name_dawn redwood  name_eastern cottonwood  \
# 0                   False              False                    False
# 1                   False              False                    False
# 2                   False              False                    False
# 3                   False              False                    False
# 4                   False              False                    False
#
#    name_eastern hemlock  name_eastern redbud  name_eastern redcedar  \
# 0                 False                False                  False
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
#
#    name_empress tree  name_false cypress  name_flowering dogwood  name_ginkgo  \
# 0              False               False                   False        False
# 1              False               False                   False        False
# 2              False               False                   False        False
# 3              False               False                   False        False
# 4              False               False                   False        False
#
#    name_golden raintree  name_green ash  name_hardy rubber tree  \
# 0                 False           False                   False
# 1                 False           False                   False
# 2                 False           False                   False
# 3                 False           False                   False
# 4                 False           False                   False
#
#    name_hawthorn  name_hedge maple  name_holly  name_honeylocust  \
# 0          False             False       False             False
# 1          False             False       False             False
# 2          False             False       False             False
# 3          False             False       False              True
# 4          False             False       False             False
#
#    name_horse chestnut  name_katsura tree  name_kousa dogwood  \
# 0                False              False               False
# 1                False              False               False
# 2                False              False               False
# 3                False              False               False
# 4                False              False               False
#
#    name_littleleaf linden  name_magnolia  name_maple  name_mulberry  \
# 0                   False          False       False          False
# 1                   False          False       False          False
# 2                   False          False       False          False
# 3                   False          False       False          False
# 4                   False          False       False          False
#
#    name_northern red oak  name_pagoda dogwood  name_paper birch  \
# 0                  False                False             False
# 1                  False                False             False
# 2                  False                False             False
# 3                  False                False             False
# 4                  False                False             False
#
#    name_paperbark maple  name_pignut hickory  name_pin oak  name_pine  \
# 0                 False                False         False      False
# 1                 False                False         False      False
# 2                 False                False         False      False
# 3                 False                False         False      False
# 4                 False                False         False      False
#
#    name_pitch pine  name_pond cypress  name_purple-leaf plum  \
# 0            False              False                  False
# 1            False              False                  False
# 2            False              False                  False
# 3            False              False                  False
# 4            False              False                  False
#
#    name_quaking aspen  name_red horse chestnut  name_red maple  name_red pine  \
# 0               False                    False           False          False
# 1               False                    False           False          False
# 2               False                    False           False          False
# 3               False                    False           False          False
# 4               False                    False           False          False
#
#    name_river birch  name_sassafras  name_sawtooth oak  name_scarlet oak  \
# 0             False           False              False             False
# 1             False           False              False             False
# 2             False           False              False             False
# 3             False           False              False             False
# 4             False           False              False             False
#
#    name_serviceberry  name_shingle oak  name_silver birch  name_silver linden  \
# 0              False             False              False               False
# 1              False             False              False               False
# 2              False             False              False               False
# 3              False             False              False               False
# 4              False             False              False               False
#
#    name_silver maple  name_southern magnolia  name_spruce  name_sugar maple  \
# 0              False                   False        False             False
# 1              False                   False        False             False
# 2              False                   False        False             False
# 3              False                   False        False             False
# 4              False                   False        False             False
#
#    name_swamp white oak  name_sweetgum  name_sycamore maple  \
# 0                 False          False                False
# 1                 False          False                False
# 2                 False          False                False
# 3                 False          False                False
# 4                 False          False                False
#
#    name_tartar maple  name_tree of heaven  name_trident maple  \
# 0              False                False               False
# 1              False                False               False
# 2              False                False               False
# 3              False                False               False
# 4              False                False               False
#
#    name_tulip-poplar  name_two-winged silverbell  name_weeping willow  \
# 0              False                       False                False
# 1              False                       False                False
# 2              False                       False                False
# 3              False                       False                False
# 4              False                       False                False
#
#    name_white ash  name_white oak  name_white pine  name_willow oak
# 0           False           False            False            False
# 1           False           False            False            False
# 2           False           False            False            False
# 3           False           False            False            False
# 4           False           False            False            False

# %%
df['curb_loc'] = df['curb_loc'].map({'OnCurb': 1, 'OffsetFromCurb': 0})
df['user_type'] = df['user_type'].map({'Volunteer': 1, 'NYC Parks Staff': 2, 'TreesCount Staff': 3})
df['steward'] = df['steward'].map({'1or2': 1, '3or4': 2, '4orMore': 3, 'None': 0})
df['guards'] = df['guards'].map({'Harmful': 2, 'Helpful': 3, 'Unsure': 1, 'None': 0})
df['sidewalk'] = df['sidewalk'].map({'Damage': 1, 'NoDamage': 0})
df.head()
# Out:
#    created_at  tree_dbh  curb_loc  health  steward  guards  sidewalk  \
# 0  2015-06-29        14         1       1        0       0         1
# 1  2016-09-21         5         1       1        2       3         0
# 2  2015-09-13        26         1       2        0       0         0
# 3  2016-05-09        15         1       0        0       0         1
# 4  2016-06-24        23         1       1        0       0         0
#
#    user_type            problems                           spc_latin   nta  \
# 0          1                None                       Quercus robur  QN45
# 1          1                None     Acer platanoides 'Crimson King'  BX05
# 2          1  StonesBranchLights                       Quercus robur  SI01
# 3          2                None  Gleditsia triacanthos var. inermis  SI11
# 4          1              Stones               Platanus x acerifolia  MN03
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist  \
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9
#
#    is_test  name_American beech  name_American elm  name_American hophornbeam  \
# 0        0                False              False                      False
# 1        0                False              False                      False
# 2        0                False              False                      False
# 3        0                False              False                      False
# 4        0                False              False                      False
#
#    name_American hornbeam  name_American linden  name_Amur cork tree  \
# 0                   False                 False                False
# 1                   False                 False                False
# 2                   False                 False                False
# 3                   False                 False                False
# 4                   False                 False                False
#
#    name_Amur maackia  name_Amur maple  name_Atlantic white cedar  \
# 0              False            False                      False
# 1              False            False                      False
# 2              False            False                      False
# 3              False            False                      False
# 4              False            False                      False
#
#    name_Atlas cedar  name_Callery pear  name_Chinese chestnut  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3             False              False                  False
# 4             False              False                  False
#
#    name_Chinese elm  name_Chinese fringetree  name_Chinese tree lilac  \
# 0             False                    False                    False
# 1             False                    False                    False
# 2             False                    False                    False
# 3             False                    False                    False
# 4             False                    False                    False
#
#    name_Cornelian cherry  name_English oak  name_European beech  \
# 0                  False              True                False
# 1                  False             False                False
# 2                  False              True                False
# 3                  False             False                False
# 4                  False             False                False
#
#    name_European hornbeam  name_Himalayan cedar  name_Japanese hornbeam  \
# 0                   False                 False                   False
# 1                   False                 False                   False
# 2                   False                 False                   False
# 3                   False                 False                   False
# 4                   False                 False                   False
#
#    name_Japanese maple  name_Japanese snowbell  name_Japanese tree lilac  \
# 0                False                   False                     False
# 1                False                   False                     False
# 2                False                   False                     False
# 3                False                   False                     False
# 4                False                   False                     False
#
#    name_Japanese zelkova  name_Kentucky coffeetree  name_Kentucky yellowwood  \
# 0                  False                     False                     False
# 1                  False                     False                     False
# 2                  False                     False                     False
# 3                  False                     False                     False
# 4                  False                     False                     False
#
#    name_London planetree  name_Norway maple  name_Norway spruce  \
# 0                  False              False               False
# 1                  False              False               False
# 2                  False              False               False
# 3                  False              False               False
# 4                   True              False               False
#
#    name_Ohio buckeye  name_Oklahoma redbud  name_Persian ironwood  \
# 0              False                 False                  False
# 1              False                 False                  False
# 2              False                 False                  False
# 3              False                 False                  False
# 4              False                 False                  False
#
#    name_Schumard's oak  name_Shantung maple  name_Siberian elm  name_Sophora  \
# 0                False                False              False         False
# 1                False                False              False         False
# 2                False                False              False         False
# 3                False                False              False         False
# 4                False                False              False         False
#
#    name_Turkish hazelnut  name_arborvitae  name_ash  name_bald cypress  \
# 0                  False            False     False              False
# 1                  False            False     False              False
# 2                  False            False     False              False
# 3                  False            False     False              False
# 4                  False            False     False              False
#
#    name_bigtooth aspen  name_black cherry  name_black locust  name_black oak  \
# 0                False              False              False           False
# 1                False              False              False           False
# 2                False              False              False           False
# 3                False              False              False           False
# 4                False              False              False           False
#
#    name_black walnut  name_blackgum  name_blue spruce  name_bur oak  \
# 0              False          False             False         False
# 1              False          False             False         False
# 2              False          False             False         False
# 3              False          False             False         False
# 4              False          False             False         False
#
#    name_catalpa  name_cherry  name_cockspur hawthorn  name_common hackberry  \
# 0         False        False                   False                  False
# 1         False        False                   False                  False
# 2         False        False                   False                  False
# 3         False        False                   False                  False
# 4         False        False                   False                  False
#
#    name_crab apple  name_crepe myrtle  name_crimson king maple  \
# 0            False              False                    False
# 1            False              False                     True
# 2            False              False                    False
# 3            False              False                    False
# 4            False              False                    False
#
#    name_cucumber magnolia  name_dawn redwood  name_eastern cottonwood  \
# 0                   False              False                    False
# 1                   False              False                    False
# 2                   False              False                    False
# 3                   False              False                    False
# 4                   False              False                    False
#
#    name_eastern hemlock  name_eastern redbud  name_eastern redcedar  \
# 0                 False                False                  False
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
#
#    name_empress tree  name_false cypress  name_flowering dogwood  name_ginkgo  \
# 0              False               False                   False        False
# 1              False               False                   False        False
# 2              False               False                   False        False
# 3              False               False                   False        False
# 4              False               False                   False        False
#
#    name_golden raintree  name_green ash  name_hardy rubber tree  \
# 0                 False           False                   False
# 1                 False           False                   False
# 2                 False           False                   False
# 3                 False           False                   False
# 4                 False           False                   False
#
#    name_hawthorn  name_hedge maple  name_holly  name_honeylocust  \
# 0          False             False       False             False
# 1          False             False       False             False
# 2          False             False       False             False
# 3          False             False       False              True
# 4          False             False       False             False
#
#    name_horse chestnut  name_katsura tree  name_kousa dogwood  \
# 0                False              False               False
# 1                False              False               False
# 2                False              False               False
# 3                False              False               False
# 4                False              False               False
#
#    name_littleleaf linden  name_magnolia  name_maple  name_mulberry  \
# 0                   False          False       False          False
# 1                   False          False       False          False
# 2                   False          False       False          False
# 3                   False          False       False          False
# 4                   False          False       False          False
#
#    name_northern red oak  name_pagoda dogwood  name_paper birch  \
# 0                  False                False             False
# 1                  False                False             False
# 2                  False                False             False
# 3                  False                False             False
# 4                  False                False             False
#
#    name_paperbark maple  name_pignut hickory  name_pin oak  name_pine  \
# 0                 False                False         False      False
# 1                 False                False         False      False
# 2                 False                False         False      False
# 3                 False                False         False      False
# 4                 False                False         False      False
#
#    name_pitch pine  name_pond cypress  name_purple-leaf plum  \
# 0            False              False                  False
# 1            False              False                  False
# 2            False              False                  False
# 3            False              False                  False
# 4            False              False                  False
#
#    name_quaking aspen  name_red horse chestnut  name_red maple  name_red pine  \
# 0               False                    False           False          False
# 1               False                    False           False          False
# 2               False                    False           False          False
# 3               False                    False           False          False
# 4               False                    False           False          False
#
#    name_river birch  name_sassafras  name_sawtooth oak  name_scarlet oak  \
# 0             False           False              False             False
# 1             False           False              False             False
# 2             False           False              False             False
# 3             False           False              False             False
# 4             False           False              False             False
#
#    name_serviceberry  name_shingle oak  name_silver birch  name_silver linden  \
# 0              False             False              False               False
# 1              False             False              False               False
# 2              False             False              False               False
# 3              False             False              False               False
# 4              False             False              False               False
#
#    name_silver maple  name_southern magnolia  name_spruce  name_sugar maple  \
# 0              False                   False        False             False
# 1              False                   False        False             False
# 2              False                   False        False             False
# 3              False                   False        False             False
# 4              False                   False        False             False
#
#    name_swamp white oak  name_sweetgum  name_sycamore maple  \
# 0                 False          False                False
# 1                 False          False                False
# 2                 False          False                False
# 3                 False          False                False
# 4                 False          False                False
#
#    name_tartar maple  name_tree of heaven  name_trident maple  \
# 0              False                False               False
# 1              False                False               False
# 2              False                False               False
# 3              False                False               False
# 4              False                False               False
#
#    name_tulip-poplar  name_two-winged silverbell  name_weeping willow  \
# 0              False                       False                False
# 1              False                       False                False
# 2              False                       False                False
# 3              False                       False                False
# 4              False                       False                False
#
#    name_white ash  name_white oak  name_white pine  name_willow oak
# 0           False           False            False            False
# 1           False           False            False            False
# 2           False           False            False            False
# 3           False           False            False            False
# 4           False           False            False            False

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    created_at  tree_dbh  curb_loc  health  steward  guards  sidewalk  \
# 0  2015-06-29        14         1       1        0       0         1
# 1  2016-09-21         5         1       1        2       3         0
# 2  2015-09-13        26         1       2        0       0         0
# 3  2016-05-09        15         1       0        0       0         1
# 4  2016-06-24        23         1       1        0       0         0
#
#    user_type            problems                           spc_latin   nta  \
# 0          1                None                       Quercus robur  QN45
# 1          1                None     Acer platanoides 'Crimson King'  BX05
# 2          1  StonesBranchLights                       Quercus robur  SI01
# 3          2                None  Gleditsia triacanthos var. inermis  SI11
# 4          1              Stones               Platanus x acerifolia  MN03
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist  \
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9
#
#    is_test  name_American beech  name_American elm  name_American hophornbeam  \
# 0        0                False              False                      False
# 1        0                False              False                      False
# 2        0                False              False                      False
# 3        0                False              False                      False
# 4        0                False              False                      False
#
#    name_American hornbeam  name_American linden  name_Amur cork tree  \
# 0                   False                 False                False
# 1                   False                 False                False
# 2                   False                 False                False
# 3                   False                 False                False
# 4                   False                 False                False
#
#    name_Amur maackia  name_Amur maple  name_Atlantic white cedar  \
# 0              False            False                      False
# 1              False            False                      False
# 2              False            False                      False
# 3              False            False                      False
# 4              False            False                      False
#
#    name_Atlas cedar  name_Callery pear  name_Chinese chestnut  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3             False              False                  False
# 4             False              False                  False
#
#    name_Chinese elm  name_Chinese fringetree  name_Chinese tree lilac  \
# 0             False                    False                    False
# 1             False                    False                    False
# 2             False                    False                    False
# 3             False                    False                    False
# 4             False                    False                    False
#
#    name_Cornelian cherry  name_English oak  name_European beech  \
# 0                  False              True                False
# 1                  False             False                False
# 2                  False              True                False
# 3                  False             False                False
# 4                  False             False                False
#
#    name_European hornbeam  name_Himalayan cedar  name_Japanese hornbeam  \
# 0                   False                 False                   False
# 1                   False                 False                   False
# 2                   False                 False                   False
# 3                   False                 False                   False
# 4                   False                 False                   False
#
#    name_Japanese maple  name_Japanese snowbell  name_Japanese tree lilac  \
# 0                False                   False                     False
# 1                False                   False                     False
# 2                False                   False                     False
# 3                False                   False                     False
# 4                False                   False                     False
#
#    name_Japanese zelkova  name_Kentucky coffeetree  name_Kentucky yellowwood  \
# 0                  False                     False                     False
# 1                  False                     False                     False
# 2                  False                     False                     False
# 3                  False                     False                     False
# 4                  False                     False                     False
#
#    name_London planetree  name_Norway maple  name_Norway spruce  \
# 0                  False              False               False
# 1                  False              False               False
# 2                  False              False               False
# 3                  False              False               False
# 4                   True              False               False
#
#    name_Ohio buckeye  name_Oklahoma redbud  name_Persian ironwood  \
# 0              False                 False                  False
# 1              False                 False                  False
# 2              False                 False                  False
# 3              False                 False                  False
# 4              False                 False                  False
#
#    name_Schumard's oak  name_Shantung maple  name_Siberian elm  name_Sophora  \
# 0                False                False              False         False
# 1                False                False              False         False
# 2                False                False              False         False
# 3                False                False              False         False
# 4                False                False              False         False
#
#    name_Turkish hazelnut  name_arborvitae  name_ash  name_bald cypress  \
# 0                  False            False     False              False
# 1                  False            False     False              False
# 2                  False            False     False              False
# 3                  False            False     False              False
# 4                  False            False     False              False
#
#    name_bigtooth aspen  name_black cherry  name_black locust  name_black oak  \
# 0                False              False              False           False
# 1                False              False              False           False
# 2                False              False              False           False
# 3                False              False              False           False
# 4                False              False              False           False
#
#    name_black walnut  name_blackgum  name_blue spruce  name_bur oak  \
# 0              False          False             False         False
# 1              False          False             False         False
# 2              False          False             False         False
# 3              False          False             False         False
# 4              False          False             False         False
#
#    name_catalpa  name_cherry  name_cockspur hawthorn  name_common hackberry  \
# 0         False        False                   False                  False
# 1         False        False                   False                  False
# 2         False        False                   False                  False
# 3         False        False                   False                  False
# 4         False        False                   False                  False
#
#    name_crab apple  name_crepe myrtle  name_crimson king maple  \
# 0            False              False                    False
# 1            False              False                     True
# 2            False              False                    False
# 3            False              False                    False
# 4            False              False                    False
#
#    name_cucumber magnolia  name_dawn redwood  name_eastern cottonwood  \
# 0                   False              False                    False
# 1                   False              False                    False
# 2                   False              False                    False
# 3                   False              False                    False
# 4                   False              False                    False
#
#    name_eastern hemlock  name_eastern redbud  name_eastern redcedar  \
# 0                 False                False                  False
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
#
#    name_empress tree  name_false cypress  name_flowering dogwood  name_ginkgo  \
# 0              False               False                   False        False
# 1              False               False                   False        False
# 2              False               False                   False        False
# 3              False               False                   False        False
# 4              False               False                   False        False
#
#    name_golden raintree  name_green ash  name_hardy rubber tree  \
# 0                 False           False                   False
# 1                 False           False                   False
# 2                 False           False                   False
# 3                 False           False                   False
# 4                 False           False                   False
#
#    name_hawthorn  name_hedge maple  name_holly  name_honeylocust  \
# 0          False             False       False             False
# 1          False             False       False             False
# 2          False             False       False             False
# 3          False             False       False              True
# 4          False             False       False             False
#
#    name_horse chestnut  name_katsura tree  name_kousa dogwood  \
# 0                False              False               False
# 1                False              False               False
# 2                False              False               False
# 3                False              False               False
# 4                False              False               False
#
#    name_littleleaf linden  name_magnolia  name_maple  name_mulberry  \
# 0                   False          False       False          False
# 1                   False          False       False          False
# 2                   False          False       False          False
# 3                   False          False       False          False
# 4                   False          False       False          False
#
#    name_northern red oak  name_pagoda dogwood  name_paper birch  \
# 0                  False                False             False
# 1                  False                False             False
# 2                  False                False             False
# 3                  False                False             False
# 4                  False                False             False
#
#    name_paperbark maple  name_pignut hickory  name_pin oak  name_pine  \
# 0                 False                False         False      False
# 1                 False                False         False      False
# 2                 False                False         False      False
# 3                 False                False         False      False
# 4                 False                False         False      False
#
#    name_pitch pine  name_pond cypress  name_purple-leaf plum  \
# 0            False              False                  False
# 1            False              False                  False
# 2            False              False                  False
# 3            False              False                  False
# 4            False              False                  False
#
#    name_quaking aspen  name_red horse chestnut  name_red maple  name_red pine  \
# 0               False                    False           False          False
# 1               False                    False           False          False
# 2               False                    False           False          False
# 3               False                    False           False          False
# 4               False                    False           False          False
#
#    name_river birch  name_sassafras  name_sawtooth oak  name_scarlet oak  \
# 0             False           False              False             False
# 1             False           False              False             False
# 2             False           False              False             False
# 3             False           False              False             False
# 4             False           False              False             False
#
#    name_serviceberry  name_shingle oak  name_silver birch  name_silver linden  \
# 0              False             False              False               False
# 1              False             False              False               False
# 2              False             False              False               False
# 3              False             False              False               False
# 4              False             False              False               False
#
#    name_silver maple  name_southern magnolia  name_spruce  name_sugar maple  \
# 0              False                   False        False             False
# 1              False                   False        False             False
# 2              False                   False        False             False
# 3              False                   False        False             False
# 4              False                   False        False             False
#
#    name_swamp white oak  name_sweetgum  name_sycamore maple  \
# 0                 False          False                False
# 1                 False          False                False
# 2                 False          False                False
# 3                 False          False                False
# 4                 False          False                False
#
#    name_tartar maple  name_tree of heaven  name_trident maple  \
# 0              False                False               False
# 1              False                False               False
# 2              False                False               False
# 3              False                False               False
# 4              False                False               False
#
#    name_tulip-poplar  name_two-winged silverbell  name_weeping willow  \
# 0              False                       False                False
# 1              False                       False                False
# 2              False                       False                False
# 3              False                       False                False
# 4              False                       False                False
#
#    name_white ash  name_white oak  name_white pine  name_willow oak
# 0           False           False            False            False
# 1           False           False            False            False
# 2           False           False            False            False
# 3           False           False            False            False
# 4           False           False            False            False

# %%
df.describe()
# Out:
#            tree_dbh      curb_loc        health       steward        guards  \
# count  39686.000000  39686.000000  39686.000000  39686.000000  39686.000000
# mean      11.647810      0.939122     -0.064380      0.313335      0.660888
# std        8.202106      0.239109      0.979576      0.571127      1.185038
# min        1.000000      0.000000     -1.000000      0.000000      0.000000
# 25%        5.000000      1.000000     -1.000000      0.000000      0.000000
# 50%        9.000000      1.000000      0.000000      0.000000      0.000000
# 75%       17.000000      1.000000      1.000000      1.000000      1.000000
# max       44.000000      1.000000      2.000000      3.000000      3.000000
#
#            sidewalk     user_type      borocode       boro_ct        cb_num  \
# count  39686.000000  39686.000000  39686.000000  3.968600e+04  39686.000000
# mean       0.466386      1.724311      3.360203  3.405672e+06    343.189210
# std        0.498875      0.878662      1.227749  1.235439e+06    121.851725
# min        0.000000      1.000000      1.000000  1.000202e+06    101.000000
# 25%        0.000000      1.000000      3.000000  3.005900e+06    301.000000
# 50%        0.000000      1.000000      4.000000  4.012100e+06    402.000000
# 75%        1.000000      3.000000      4.000000  4.119500e+06    413.000000
# max        1.000000      3.000000      5.000000  5.031902e+06    503.000000
#
#           st_senate      st_assem      cncldist       is_test
# count  39686.000000  39686.000000  39686.000000  39686.000000
# mean      21.052487     51.744494     30.281485      0.496447
# std        7.198739     18.657595     14.773305      0.499994
# min       10.000000     23.000000      1.000000      0.000000
# 25%       15.000000     33.000000     19.000000      0.000000
# 50%       22.000000     55.000000     31.000000      0.000000
# 75%       25.000000     64.000000     44.000000      1.000000
# max       36.000000     87.000000     51.000000      1.000000

# %%
df.loc[df['guards'].isnull()]
# Out:
# Empty DataFrame
# Columns: [created_at, tree_dbh, curb_loc, health, steward, guards, sidewalk, user_type, problems, spc_latin, nta, nta_name, borocode, boro_ct, boroname, zip_city, cb_num, st_senate, st_assem, cncldist, is_test, name_American beech, name_American elm, name_American hophornbeam, name_American hornbeam, name_American linden, name_Amur cork tree, name_Amur maackia, name_Amur maple, name_Atlantic white cedar, name_Atlas cedar, name_Callery pear, name_Chinese chestnut, name_Chinese elm, name_Chinese fringetree, name_Chinese tree lilac, name_Cornelian cherry, name_English oak, name_European beech, name_European hornbeam, name_Himalayan cedar, name_Japanese hornbeam, name_Japanese maple, name_Japanese snowbell, name_Japanese tree lilac, name_Japanese zelkova, name_Kentucky coffeetree, name_Kentucky yellowwood, name_London planetree, name_Norway maple, name_Norway spruce, name_Ohio buckeye, name_Oklahoma redbud, name_Persian ironwood, name_Schumard's oak, name_Shantung maple, name_Siberian elm, name_Sophora, name_Turkish hazelnut, name_arborvitae, name_ash, name_bald cypress, name_bigtooth aspen, name_black cherry, name_black locust, name_black oak, name_black walnut, name_blackgum, name_blue spruce, name_bur oak, name_catalpa, name_cherry, name_cockspur hawthorn, name_common hackberry, name_crab apple, name_crepe myrtle, name_crimson king maple, name_cucumber magnolia, name_dawn redwood, name_eastern cottonwood, name_eastern hemlock, name_eastern redbud, name_eastern redcedar, name_empress tree, name_false cypress, name_flowering dogwood, name_ginkgo, name_golden raintree, name_green ash, name_hardy rubber tree, name_hawthorn, name_hedge maple, name_holly, name_honeylocust, name_horse chestnut, name_katsura tree, name_kousa dogwood, name_littleleaf linden, name_magnolia, name_maple, ...]
# Index: []

# %%
df.fillna('NULL', inplace=True)

# %%
df.loc[df['guards'].isnull()]
# Out:
# Empty DataFrame
# Columns: [created_at, tree_dbh, curb_loc, health, steward, guards, sidewalk, user_type, problems, spc_latin, nta, nta_name, borocode, boro_ct, boroname, zip_city, cb_num, st_senate, st_assem, cncldist, is_test, name_American beech, name_American elm, name_American hophornbeam, name_American hornbeam, name_American linden, name_Amur cork tree, name_Amur maackia, name_Amur maple, name_Atlantic white cedar, name_Atlas cedar, name_Callery pear, name_Chinese chestnut, name_Chinese elm, name_Chinese fringetree, name_Chinese tree lilac, name_Cornelian cherry, name_English oak, name_European beech, name_European hornbeam, name_Himalayan cedar, name_Japanese hornbeam, name_Japanese maple, name_Japanese snowbell, name_Japanese tree lilac, name_Japanese zelkova, name_Kentucky coffeetree, name_Kentucky yellowwood, name_London planetree, name_Norway maple, name_Norway spruce, name_Ohio buckeye, name_Oklahoma redbud, name_Persian ironwood, name_Schumard's oak, name_Shantung maple, name_Siberian elm, name_Sophora, name_Turkish hazelnut, name_arborvitae, name_ash, name_bald cypress, name_bigtooth aspen, name_black cherry, name_black locust, name_black oak, name_black walnut, name_blackgum, name_blue spruce, name_bur oak, name_catalpa, name_cherry, name_cockspur hawthorn, name_common hackberry, name_crab apple, name_crepe myrtle, name_crimson king maple, name_cucumber magnolia, name_dawn redwood, name_eastern cottonwood, name_eastern hemlock, name_eastern redbud, name_eastern redcedar, name_empress tree, name_false cypress, name_flowering dogwood, name_ginkgo, name_golden raintree, name_green ash, name_hardy rubber tree, name_hawthorn, name_hedge maple, name_holly, name_honeylocust, name_horse chestnut, name_katsura tree, name_kousa dogwood, name_littleleaf linden, name_magnolia, name_maple, ...]
# Index: []

# %%
df.columns
# Out:
# Index(['created_at', 'tree_dbh', 'curb_loc', 'health', 'steward', 'guards',
#        'sidewalk', 'user_type', 'problems', 'spc_latin',
#        ...
#        'name_tartar maple', 'name_tree of heaven', 'name_trident maple',
#        'name_tulip-poplar', 'name_two-winged silverbell',
#        'name_weeping willow', 'name_white ash', 'name_white oak',
#        'name_white pine', 'name_willow oak'],
#       dtype='object', length=140)

# %%
# 'is_test' 列を使って元の train と test データセットに戻す
train = df[df['is_test'] == 0].drop(columns=['is_test'])
test = df[df['is_test'] == 1].drop(columns=['is_test', 'health'])

# %%
columns_to_drop = ['created_at', 'problems', 'spc_latin', 'nta', 'nta_name', 'boroname', 'zip_city']
X = train.drop(columns_to_drop, axis=1)
y = train['health']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state = 42)

# %%
y_train.value_counts(normalize=True)
# Out:
# health
# 1    0.788164
# 0    0.176875
# 2    0.034961
# Name: proportion, dtype: float64

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_train, y_train), lr.score(X_test, y_test)
# Out:
# (0.7881638644248732, 0.7882305844675741)

# %%
rfc_1 = RandomForestClassifier(random_state = 42)
rfc_1.fit(X_train, y_train)
rfc_1.score(X_train, y_train), rfc_1.score(X_test, y_test)
# Out:
# (1.0, 0.9973979183346677)

# %%
rfc_2 = RandomForestClassifier(n_estimators = 100, max_depth = 6, random_state = 42)
rfc_2.fit(X_train, y_train)
rfc_2.score(X_train, y_train), rfc_2.score(X_test, y_test)
# Out:
# (0.9599679743795037, 0.9575660528422738)

# %%
dt_1 = DecisionTreeClassifier(random_state = 42)
dt_1.fit(X_train, y_train)
dt_1.score(X_train, y_train), dt_1.score(X_test, y_test)
# Out:
# (1.0, 1.0)

# %%
dt_2 = DecisionTreeClassifier(max_depth = 5, 
                            min_samples_split = 10, 
                            min_samples_leaf = 3, 
                            random_state = 42)
dt_2.fit(X_train, y_train)
dt_2.score(X_train, y_train), dt_2.score(X_test, y_test)
# Out:
# (1.0, 1.0)
